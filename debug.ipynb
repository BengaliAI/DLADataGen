# %%
from coreLib.dataset import DataSet
data_dir="/home/ansary/WORK/Work/APSIS/datasets/DLA/source/"
ds=DataSet(data_dir)
# Out:
# ...
# 100%|██████████| 3240/3240 [00:00<00:00, 2614882.62it/s]
# #LOG     :Collected bangla font paths:17
# #LOG     :Collected english font paths:68
# #LOG     :Collected sign paths:3240

# %%
from coreLib.data import create_paragraph,create_text_line
import matplotlib.pyplot as plt
import cv2
img,iden=create_paragraph(ds,"bangla",2,"middle")
#img,iden=create_text_line(ds,"bangla",2)
import numpy as np
h,w=img.shape
viz=np.ones((h,w,3))*255
viz=viz.astype("uint8")
viz[img>0]=(0,0,0) 
plt.imshow(viz)
cv2.imwrite("test.png",viz)
# Out:
# True

# %%
{
0: "image",
1: "text",
2: "table",
3: "numbered list",
4: "sign",
5: "paragraph",
6: "nothing",
7: "noise"
 }

# alignment-> matra
# forced sizing
# bold,italic,underline-->data
# placement: column
# render:
